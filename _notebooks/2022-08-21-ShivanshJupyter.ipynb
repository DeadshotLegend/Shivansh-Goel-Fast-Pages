# %% [markdown]
# # Shivansh Goel's First Python Code and use of Jupyter Notebook
#
# ### This is python code of printing a String

# %%
print("Hello, world!")
# Out:
# Hello, world!
